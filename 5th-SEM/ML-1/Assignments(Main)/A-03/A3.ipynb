# %% [markdown]
# ### Major Assignment – 2 (Chapter 3 – 4)
# ### Part B – Lab Questions

# %% [markdown]
# ### Q1.  Write a Python program to generate Bernoulli and Binomial distributions using NumPy and calculate their mean and variance.

# %%
import numpy as np

p = 0.5
bern = np.random.binomial(1, p, 1000)
print("Bernoulli Mean:", np.mean(bern))
print("Bernoulli Variance:", np.var(bern))

n = 10
binom = np.random.binomial(n, p, 1000)
print("Binomial Mean:", np.mean(binom))
print("Binomial Variance:", np.var(binom))
# Out:
# Bernoulli Mean: 0.502
# Bernoulli Variance: 0.2499959999999999
# Binomial Mean: 5.082
# Binomial Variance: 2.633276

# %% [markdown]
# ### Q2. Write a Python program to generate random samples from a Normal distribution and plot its Probability Density Function (PDF).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

data = np.random.normal(0, 1, 1000)
x = np.linspace(-5, 5, 50)
plt.plot(x, norm.pdf(x, 0, 1))
plt.show()

# %% [markdown]
# ### Q3. Write a Python program to compute and display the covariance and correlation coefficient between two random variables.

# %%
import numpy as np

x = np.random.rand(3000)
y = np.random.rand(3000)

cov = np.cov(x, y)
corr = np.corrcoef(x, y)

print("Covariance:\n", cov)
print("Correlation:\n", corr)
# Out:
# Covariance:
#  [[0.08089948 0.00037219]
#  [0.00037219 0.08247934]]
# Correlation:
#  [[1.         0.00455643]
#  [0.00455643 1.        ]]

# %% [markdown]
# ### Q4. Write a Python program to verify the Central Limit Theorem (CLT) by plotting the distribution of sample means.

# %%
import numpy as np
import matplotlib.pyplot as plt

means = []
for i in range(500):
    sample = np.random.rand(50)
    means.append(sample.mean())

plt.hist(means, bins=10)
plt.title("CLT Verification")
plt.show()

# %% [markdown]
# ### Q5. Write a Python program to implement kNN classifier for a given dataset
# *(Iris.csv, apndcts.csv, btisuue.csv)*
#
# **The program should:**
# - Load a dataset from a CSV file using Pandas
# - Separate predictor variables and target class labels
# - Split the dataset into training and testing sets
# - Train a kNN model using the training data
# - Predict class labels for the test data
# - Compute and display the accuracy of the model

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

data = pd.read_csv("btissue.csv")
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

model = KNeighborsClassifier(n_neighbors=7)
model.fit(X_train, y_train)

pred = model.predict(X_test)
print(accuracy_score(y_test, pred))
# Out:
# 0.40625
